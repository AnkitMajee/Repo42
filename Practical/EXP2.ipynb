# %% [markdown]
# Generate a random (100x100) matrix
# Find for each column (feature)
# 1. Mean
# 2. Variance
# 3. Kurtosis
# 4. Skewness
#
# Plot 4 graphs of above 4 metrics for each column.

# %%
import numpy as np
import pandas as pd
from scipy.stats import kurtosis, skew

# Generate a random (100x100) matrix
matrix = np.random.rand(100, 100)
print(matrix)
# Out:
# [[0.36428736 0.01010302 0.66838606 ... 0.22903171 0.29241349 0.56745856]
#  [0.53214758 0.10628432 0.86195641 ... 0.32243926 0.68826327 0.95931085]
#  [0.3197525  0.3516993  0.13355173 ... 0.44961147 0.19264587 0.72970325]
#  ...
#  [0.02680368 0.77255508 0.39203161 ... 0.40923224 0.66186097 0.59726678]
#  [0.225961   0.51391982 0.58804622 ... 0.17074404 0.23696379 0.16219386]
#  [0.05900845 0.42825758 0.71430411 ... 0.9195605  0.43680888 0.97839401]]

# %%
# Calculate metrics for all columns
means = np.mean(matrix, axis=0)
variances = np.var(matrix, axis=0)
kurtoses = kurtosis(matrix, axis=0)
skewnesses = skew(matrix, axis=0)

df = pd.DataFrame({
    'Column': range(matrix.shape[1]),
    'Mean': means,
    'Variance': variances,
    'Kurtosis': kurtoses,
    'Skewness': skewnesses
})

df
# Out:
#     Column      Mean  Variance  Kurtosis  Skewness
# 0        0  0.458454  0.078669 -1.052975  0.113206
# 1        1  0.439876  0.073022 -1.049915  0.178104
# 2        2  0.528650  0.076727 -1.129841 -0.045978
# 3        3  0.486977  0.085868 -1.219340  0.125075
# 4        4  0.470016  0.083673 -1.102940  0.080265
# ..     ...       ...       ...       ...       ...
# 95      95  0.509294  0.080637 -1.156233 -0.099440
# 96      96  0.504825  0.087712 -1.205879 -0.097149
# 97      97  0.481941  0.081386 -1.175694  0.130798
# 98      98  0.471203  0.085646 -1.229317  0.150140
# 99      99  0.504110  0.091429 -1.266883  0.069663
#
# [100 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# Plot the metrics
plt.figure(figsize=(15, 8))

plt.subplot(2, 2, 1)
plt.plot(df['Column'], df['Mean'], marker='o')
plt.xlabel('Column')
plt.ylabel('Mean')
plt.title('Mean of Each Column')

plt.subplot(2, 2, 2)
plt.plot(df['Column'], df['Variance'], marker='o')
plt.xlabel('Column')
plt.ylabel('Variance')
plt.title('Variance of Each Column')

plt.subplot(2, 2, 3)
plt.plot(df['Column'], df['Kurtosis'], marker='o')
plt.xlabel('Column')
plt.ylabel('Kurtosis')
plt.title('Kurtosis of Each Column')

plt.subplot(2, 2, 4)
plt.plot(df['Column'], df['Skewness'], marker='o')
plt.xlabel('Column')
plt.ylabel('Skewness')
plt.title('Skewness of Each Column')

plt.tight_layout()
plt.show()
